# %%
# Import Dependencies
import pandas as pd

# %%
# Import our data into pandas from CSV
injury_string = '../Tableau/Tableau Project 3/Resources/injuries.csv'
injury_df = pd.read_csv(injury_string)

injury_df
# Out:
#             Date          Team        Acquired  \
# 0      10/3/2010         Bulls             NaN
# 1      10/6/2010       Pistons             NaN
# 2      10/6/2010       Pistons             NaN
# 3      10/8/2010       Blazers             NaN
# 4      10/8/2010          Nets             NaN
# 5      10/8/2010       Pistons             NaN
# 6      10/8/2010       Pistons             NaN
# 7      10/9/2010       Nuggets             NaN
# 8     10/12/2010         Bucks             NaN
# 9     10/12/2010         Kings             NaN
# 10    10/17/2010       Bobcats             NaN
# 11    10/18/2010      Warriors             NaN
# 12    10/19/2010          Suns             NaN
# 13    10/22/2010          Heat             NaN
# 14    10/25/2010       Thunder             NaN
# 15    10/25/2010  Timberwolves             NaN
# 16    10/26/2010          Heat             NaN
# 17    10/27/2010         Bucks             NaN
# 18    10/27/2010         Bucks             NaN
# ...
